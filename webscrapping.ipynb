# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install bs4
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install html5lib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install urllib3
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import urllib.request as urllib2

# %%
pip install bs4
# Out:
# ...
#
# ...

# %%
import time 
from datetime import datetime
import pandas as pd
import requests
from bs4 import BeautifulSoup 

url="https://www.mastec.com/expertise/oil-gas/pipeline-construction"

mahi= requests.get(url)
print(mahi.status_code)

htmlcontent=mahi.content
print(htmlcontent)
# Out:
# 200
# ...

# %%
#Parse the html content 

soup = BeautifulSoup(htmlcontent, "html.parser")

print(soup)

print(soup.prettify )
# Out:
# <!DOCTYPE html>
#
# <html lang="en" xmlns="http://www.w3.org/1999/xhtml">
# <head>
# <meta content="width=device-width, initial-scale=1" name="viewport"/>
# <title>Oil And Natural Gas Pipeline Construction | MasTec</title>
# <link href="/areas/cms/assets/img/favicon.png" rel="shortcut icon"/>
# <meta content="As one of the nation's leading oil and natural gas pipeline construction companies, MasTec provides the innovation, capabilities and resources to meet the demand for upstream, midstream and distribution construction for oil and natural gas pipelines. " name="description"/>
# <meta content="MasTec, Jose Mas CEO, construction, oil pipeline construction, natural gas pipeline construction, natural gas facility construction" name="keywords"/>
# <!-- Favicon -->
# <link href="/apple-touch-icon.png" rel="apple-touch-icon" sizes="180x180"/>
# <link href="/favicon.png" rel="icon" sizes="32x32" type="image/png"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# ...

# %%
#priting title of web page

print(soup.findAll('title'))

#It will give all the div in html page

print(soup.findAll('div'))

#It will give all the text files in the html page 

print(soup.findAll('text'))

#It will give an anchor tag of number fourth in web page

one_tag = soup.find_all(isAnchortextwithLargeText, Limit = 10)

print(one_tag)
# Out:
# [<title>Oil And Natural Gas Pipeline Construction | MasTec</title>]
# [<div id="sb-site">
# <div class="sr-only" itemscope="" itemtype="http://schema.org/WebPage">
# <span itemprop="name">MasTec | Infrastructure that Delivers</span>
# <span itemprop="description">Leading specialty contractor engineers, designs and constructs infrastructures for electric power generation and transmission, oil and natural gas pipelines, renewable energy facilities and wireless networks.</span>
# </div>
# <header class="container-fluid" data-offset-top="100" data-spy="affix" id="header">
# <div class="row flex-row flex-center">
# <!-- Logo -->
# <div class="bg-transparent" id="logo">
# <a class="logo-white" href="/"><img alt="MasTec | Home" src="/Areas/CMS/assets/img/MasTec_logo.png"/></a>
# <a href="/"><img alt="MasTec | Home" src="/Areas/CMS/assets/img/MasTec_logo.png"/></a>
# </div>
# <!-- Main Navigation -->
# <div class="header-right flex-1">
# ...

# %%
# get all the links from html page
anchor=soup.findAll('a')

all_link=set()

for link in anchor:
    
     if (link.get('href') != '#'):

       linkprint="https://www.mastec.com/expertise/oil-gas/pipeline-construction"+link.get('href')

       all_link.add(link)

       print(linkprint)
# Out:
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/communication/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/oil-gas/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/power-generation/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/power-delivery/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/civil-industrial/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/technology-deployment/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/expertise/water-sewer/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/projects/
# https://www.mastec.com/expertise/oil-gas/pipeline-construction/about/
# ...
